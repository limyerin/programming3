# %%
import pandas as pd
import numpy as np

# %%
movie = pd.read_csv('data/movie.csv', nrows=1000)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      997 non-null    object
#  1   director_name              982 non-null    object
#  2   num_critic_for_reviews     998 non-null    float64
#  3   duration                   997 non-null    float64
#  4   director_facebook_likes    982 non-null    float64
#  5   actor_3_facebook_likes     998 non-null    float64
#  6   actor_2_name               999 non-null    object
#  7   actor_1_facebook_likes     1000 non-null   float64
#  8   gross                      965 non-null    float64
#  9   genres                     1000 non-null   object
#  10  actor_1_name               1000 non-null   object
#  11  movie_title                1000 non-null   object
#  12  num_voted_users            1000 non-null   int64
# ...

# %%
np.finfo('float64')
# Out:
# finfo(resolution=1e-15, min=-1.7976931348623157e+308, max=1.7976931348623157e+308, dtype=float64)

# %%
np.finfo('float32')
# Out:
# finfo(resolution=1e-06, min=-3.4028235e+38, max=3.4028235e+38, dtype=float32)

# %%
np.finfo('float16')
# Out:
# finfo(resolution=0.001, min=-6.55040e+04, max=6.55040e+04, dtype=float16)

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie.describe().T
# Out:
#                             count          mean           std         min  \
# num_critic_for_reviews      998.0  2.246503e+02  1.418149e+02        1.00
# duration                    997.0  1.167242e+02  2.616562e+01       22.00
# director_facebook_likes     982.0  1.310123e+03  4.033584e+03        0.00
# actor_3_facebook_likes      998.0  1.298911e+03  2.845385e+03        0.00
# actor_1_facebook_likes     1000.0  1.066608e+04  1.124150e+04        2.00
# gross                       965.0  1.094586e+08  9.596531e+07     9213.00
# num_voted_users            1000.0  1.775484e+05  1.981364e+05        6.00
# cast_total_facebook_likes  1000.0  1.662582e+04  1.758710e+04        2.00
# facenumber_in_poster        998.0  1.224449e+00  1.703652e+00        0.00
# num_user_for_reviews        998.0  5.274569e+02  5.719146e+02        1.00
# budget                      961.0  9.230017e+07  4.665297e+07  1400000.00
# title_year                  980.0  2.005715e+03  6.702154e+00     1962.00
# ...

# %%
np.iinfo('int64')
# Out:
# iinfo(min=-9223372036854775808, max=9223372036854775807, dtype=int64)

# %%
np.iinfo('int32')
# Out:
# iinfo(min=-2147483648, max=2147483647, dtype=int32)

# %%
np.iinfo('int16')
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
#정보 손실 있을 수도 있음
np.iinfo('int8')
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
movie2 = pd.read_csv('data/movie.csv', nrows=1000,
                       dtype={
                           'num_critic_for_reviews': np.float16,
                           'duration': np.float16,
                           'director_facebook_likes': np.float16,
                           'actor_3_facebook_likes': np.float16,
                           'actor_1_facebook_likes': np.float16,
                           'gross': np.float16,
                           'facenumber_in_poster': np.float16,
                           'num_user_for_reviews': np.float16,
                           'budget': np.float16,
                           'title_year': np.float16,
                           'actor_2_facebook_likes': np.float16,
                           'imdb_score': np.float16,
                           'aspect_ratio': np.float16,
                           'num_voted_users': np.int16,
                           'cast_total_facebook_likes': np.int16,
                           'movie_facebook_likes': np.int16
                       })
movie2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      997 non-null    object
#  1   director_name              982 non-null    object
#  2   num_critic_for_reviews     998 non-null    float16
#  3   duration                   997 non-null    float16
#  4   director_facebook_likes    982 non-null    float16
#  5   actor_3_facebook_likes     998 non-null    float16
#  6   actor_2_name               999 non-null    object
#  7   actor_1_facebook_likes     1000 non-null   float16
#  8   gross                      965 non-null    float16
#  9   genres                     1000 non-null   object
#  10  actor_1_name               1000 non-null   object
#  11  movie_title                1000 non-null   object
#  12  num_voted_users            1000 non-null   int16
# ...

# %%
round(125.1/218.9, 2)
# Out:
# 0.57

# %%
movie2.describe(include='O')
# Out:
#         color     director_name    actor_2_name                   genres  \
# count     997               982             999                     1000
# unique      2               469             695                      371
# top     Color  Steven Spielberg  Morgan Freeman  Action|Adventure|Sci-Fi
# freq      973                15              11                       39
#
#        actor_1_name movie_title  actor_3_name  \
# count          1000        1000           998
# unique          427        1000           823
# top      Will Smith      Avatar  Steve Coogan
# freq             17           1             7
#
#                                  plot_keywords  \
# count                                      992
# unique                                     992
# top     avatar|future|marine|native|paraplegic
# freq                                         1
#
#                                           movie_imdb_link language country  \
# ...

# %%
movie2.color.value_counts()
# Out:
# Color              973
# Black and White     24
# Name: color, dtype: int64

# %%
movie2.director_name.value_counts()
# Out:
# Steven Spielberg    15
# Ridley Scott        10
# Ron Howard          10
# Michael Bay         10
# Clint Eastwood       8
#                     ..
# David Kellogg        1
# Dan Scanlon          1
# Robert Luketic       1
# Gil Kenan            1
# John Carpenter       1
# Name: director_name, Length: 469, dtype: int64

# %%
movie2.actor_2_name.value_counts()
# Out:
# Morgan Freeman         11
# Adam Sandler            8
# Orlando Bloom           7
# Brad Pitt               6
# Angelina Jolie Pitt     6
#                        ..
# Leven Rambin            1
# George Harris           1
# Kim Dickens             1
# Rachael Harris          1
# Brittany Curran         1
# Name: actor_2_name, Length: 695, dtype: int64

# %%
movie3 = pd.read_csv('data/movie.csv', nrows=1000,
                       dtype={
                           'num_critic_for_reviews': np.float16,
                           'duration': np.float16,
                           'director_facebook_likes': np.float16,
                           'actor_3_facebook_likes': np.float16,
                           'actor_1_facebook_likes': np.float16,
                           'gross': np.float16,
                           'facenumber_in_poster': np.float16,
                           'num_user_for_reviews': np.float16,
                           'budget': np.float16,
                           'title_year': np.float16,
                           'actor_2_facebook_likes': np.float16,
                           'imdb_score': np.float16,
                           'aspect_ratio': np.float16,
                           'num_voted_users': np.int16,
                           'cast_total_facebook_likes': np.int16,
                           'movie_facebook_likes': np.int16,
                           'color': 'category',
                           'director_name': 'category',
                           'actor_2_name': 'category',
                           'genres': 'category',
                           'actor_1_name': 'category',
                           'movie_title': 'category',
                           'actor_3_name': 'category',
                           'plot_keywords': 'category',
                           'movie_imdb_link': 'category',
                           'language': 'category',
                           'country': 'category',
                           'content_rating': 'category'
                       })
movie3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      997 non-null    category
#  1   director_name              982 non-null    category
#  2   num_critic_for_reviews     998 non-null    float16
#  3   duration                   997 non-null    float16
#  4   director_facebook_likes    982 non-null    float16
#  5   actor_3_facebook_likes     998 non-null    float16
#  6   actor_2_name               999 non-null    category
#  7   actor_1_facebook_likes     1000 non-null   float16
#  8   gross                      965 non-null    float16
#  9   genres                     1000 non-null   category
#  10  actor_1_name               1000 non-null   category
#  11  movie_title                1000 non-null   category
#  12  num_voted_users            1000 non-null   int16
# ...

# %%
cols = ['color', 'director_name', 'num_critic_for_reviews', 'duration', 'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name', 'actor_1_facebook_likes', 'gross', 
        'genres', 'actor_1_name', 'movie_title', 'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name', 'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
        'num_user_for_reviews', 'language', 'country', 'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes']

movie_iter = pd.read_csv('data/movie.csv', nrows=1000,
                       dtype={
                           'num_critic_for_reviews': np.float16,
                           'duration': np.float16,
                           'director_facebook_likes': np.float16,
                           'actor_3_facebook_likes': np.float16,
                           'actor_1_facebook_likes': np.float16,
                           'gross': np.float16,
                           'facenumber_in_poster': np.float16,
                           'num_user_for_reviews': np.float16,
                           'budget': np.float16,
                           'title_year': np.float16,
                           'actor_2_facebook_likes': np.float16,
                           'imdb_score': np.float16,
                           'aspect_ratio': np.float16,
                           'num_voted_users': np.int16,
                           'cast_total_facebook_likes': np.int16,
                           'movie_facebook_likes': np.int16,
                           'color': 'category',
                           'director_name': 'category',
                           'actor_2_name': 'category',
                           'genres': 'category',
                           'actor_1_name': 'category',
                           'movie_title': 'category',
                           'actor_3_name': 'category',
                           'plot_keywords': 'category',
                           'movie_imdb_link': 'category',
                           'language': 'category',
                           'country': 'category',
                           'content_rating': 'category'
                       },
                       usecols=cols,
                       chunksize=300  #이 부분이죠!
                       )

def process(df):
    return f'processed {df.shape} shape of df {df.iloc[0, :]}'

for chunk in movie_iter:
    print(process(chunk))
# Out:
# processed (300, 25) shape of df color                                                                    Color
# director_name                                                    James Cameron
# num_critic_for_reviews                                                   723.0
# duration                                                                 178.0
# director_facebook_likes                                                    0.0
# actor_3_facebook_likes                                                   855.0
# actor_2_name                                                  Joel David Moore
# actor_1_facebook_likes                                                  1000.0
# gross                                                                      inf
# genres                                         Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                       CCH Pounder
# ...
